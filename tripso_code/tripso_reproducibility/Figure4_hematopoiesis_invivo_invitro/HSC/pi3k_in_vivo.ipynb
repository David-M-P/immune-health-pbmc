# %%
import scanpy as sc
import pandas as pd
from tripso.Evaluate.downstream import calculate_gene_significance, plot_top_genes
import numpy as np
import anndata as ad
import os

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42

# %%
def load_adata(run, output_name = 'global'):
    holder = []
    base_path = 'tripso_reproducibility/04.4_HSC_fix_hvg'
    

    for t in ['train', 'val', 'test']:
        target_path = f'gene_embedding_analysis/PI3K_cd34_hspc/gene_to_PI3K_cosine_similarity_{t}_set.h5ad'
        holder.append(
            sc.read_h5ad(os.path.join(base_path, f'{run}_by_study/output_{output_name}', target_path))
        )
        
    adata = ad.concat(holder)    
    
    return adata

# %%
run1 = load_adata('run_1')
run2 = load_adata('run_2')
run3 = load_adata('run_3')
# Out:
# /software/cellgen/team292/mm58/venvs/lightning2/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# /software/cellgen/team292/mm58/venvs/lightning2/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
# /software/cellgen/team292/mm58/venvs/lightning2/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.

# %%
# sanity check
run1.obs == run2.obs
run2.obs == run3.obs
run1.var == run2.var
run3.var == run3.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [ENSG00000006047, ENSG00000007255, ENSG00000010626, ENSG00000023909, ENSG00000024862, ENSG00000036565, ENSG00000046647, ENSG00000046653, ENSG00000050426, ENSG00000057663, ENSG00000065029, ENSG00000066185, ENSG00000070759, ENSG00000076344, ENSG00000076706, ENSG00000077498, ENSG00000087053, ENSG00000088882, ENSG00000089289, ENSG00000090520, ENSG00000090581, ENSG00000091137, ENSG00000095397, ENSG00000099958, ENSG00000100027, ENSG00000100246, ENSG00000100307, ENSG00000100324, ENSG00000102796, ENSG00000103051, ENSG00000104413, ENSG00000104870, ENSG00000104883, ENSG00000105755, ENSG00000106479, ENSG00000106624, ENSG00000108262, ENSG00000108465, ENSG00000109794, ENSG00000111653, ENSG00000112333, ENSG00000113851, ENSG00000114126, ENSG00000114544, ENSG00000114626, ENSG00000114742, ENSG00000114796, ENSG00000117305, ENSG00000117691, ENSG00000118298, ENSG00000119688, ENSG00000119711, ENSG00000120215, ENSG00000121749, ENSG00000122133, ENSG00000124783, ENSG00000125744, ENSG00000129518, ENSG00000129991, ENSG00000130203, ENSG00000130208, ENSG00000130304, ENSG00000131711, ENSG00000132376, ENSG00000132879, ENSG00000136881, ENSG00000137274, ENSG00000138347, ENSG00000138433, ENSG00000139278, ENSG00000139344, ENSG00000140545, ENSG00000143127, ENSG00000143303, ENSG00000143578, ENSG00000144115, ENSG00000144579, ENSG00000144741, ENSG00000146083, ENSG00000146830, ENSG00000147364, ENSG00000147419, ENSG00000148225, ENSG00000148908, ENSG00000149292, ENSG00000152684, ENSG00000152763, ENSG00000153391, ENSG00000157833, ENSG00000157873, ENSG00000157954, ENSG00000158022, ENSG00000159111, ENSG00000160678, ENSG00000162032, ENSG00000162894, ENSG00000163050, ENSG00000163794, ENSG00000164463, ENSG00000164615, ...]
#
# [151 rows x 0 columns]

# %%
adata = sc.AnnData(
    X = (run1.X + run2.X + run3.X)/3,
    obs = run1.obs,
    var = run1.var
)
# Out:
# /software/cellgen/team292/mm58/venvs/lightning2/lib/python3.10/site-packages/anndata/_core/anndata.py:1754: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.

# %%
# map ensembl to gene name 
from geneformer import ENSEMBL_DICTIONARY_FILE
name_to_ens = pd.read_pickle(ENSEMBL_DICTIONARY_FILE)
name_df = pd.DataFrame(
            list(name_to_ens.items()), columns=['gene', 'ensembl_id']
        )

convert_df = name_df[name_df['ensembl_id'].isin(adata.var_names)]

# gpdb_symbol = pd.read_csv('../../gp_nw_all.csv')
gpdb_symbol = pd.read_csv('tripso_reproducibility/02.1_benchmarking_repeat/gpdb_progeny_200.csv')

convert_df = convert_df[convert_df['gene'].isin(gpdb_symbol['PI3K'].values)]

# %%
adata.var = adata.var.join(convert_df.set_index('ensembl_id'))

# %%
adata.var = adata.var.set_index('gene')

# %%
adata.obs['cell_type_binary'] = np.where(
    adata.obs['cell_type'].str.contains('LT-HSC'),
    'LT-HSC',
    'other'
)

# %%
# AnnData (sparse native, zeros treated as 0)
res = calculate_gene_significance(
    adata,
    obs_col="cell_type_binary",
    obs_value_ref="other",
    obs_value_query="LT-HSC",
    adata_gene_threshold=0.9,   # same semantics as before
)

# %%
plot_top_genes(
    res,
    obs_value_ref="other",
    obs_value_query="LT-HSC",
    show_significance=False,
    color_scheme='significance',
    significance_palette=['lightsteelblue', 'lightsteelblue'],  # list OK
    palette_as_gradient=True,   # uses the two colors to build gradients
    topn=10,
    figsize=(9, 7),
)
# Out:
# /nfs/team361/mm58/tripso/tripso/Evaluate/downstream.py:2223: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1, 0].set_yticklabels(yticklabels)
# /nfs/team361/mm58/tripso/tripso/Evaluate/downstream.py:2308: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1, 1].set_yticklabels(yticklabels)

# %%
# AnnData (sparse native, zeros treated as 0)
res = calculate_gene_significance(
    adata,
    obs_col="cell_type_binary",
    obs_value_ref="LT-HSC",
    obs_value_query="other",
    adata_gene_threshold=0.9,   # same semantics as before
)

# %%
plot_top_genes(
    res,
    obs_value_ref="LT-HSC",
    obs_value_query="other",
    show_significance=False,
    color_scheme='significance',
    significance_palette=['lightsteelblue', 'lightsteelblue'],  # list OK
    palette_as_gradient=True,   # uses the two colors to build gradients
    topn=10,
    figsize=(9, 7),
    save_to='pi3k_hsc.pdf'
)
# Out:
# /nfs/team361/mm58/tripso/tripso/Evaluate/downstream.py:2223: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1, 0].set_yticklabels(yticklabels)
# /nfs/team361/mm58/tripso/tripso/Evaluate/downstream.py:2308: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs[1, 1].set_yticklabels(yticklabels)
